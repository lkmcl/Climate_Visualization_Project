# %% [markdown]
# ## Visualizing Global Temperature Anomalies
#
# Run the cell below in order to generate dropdown menus for viewing global temperature anomalies. Upon selecting a year (1890-2021) and a month of interest, a map of gridded temperature anomalies compared to the 1981-2010 averages for that cell are visualized. Upon changing the inputs in the dropdown menus, the plotting will self update without the cell having to be rerun.

# %%
## Must be ran for generation of the dropdown menus
from Interactive_Climate_Visualization import Global_Temperature_Anomalies_Analysis

Global_Temperature_Anomalies_Analysis()

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## Visualizing City Average Temperature Time Series
#
# Run the cell below in order to generate dropdown menus for viewing a time series of average temperatures for a particular city. Upon selecting a city of the ten options available, the user can then select either "annual" or a month of interest to illustrate the average temperatures each year across this particular time scale. A time series is illustrated as well as a line of the 1981-2010 mean for comparison. The default time range for the series is 1890-2021 but both the start year and end year can be adjusted to view specific time ranges. Upon changing the inputs in the dropdown menus, the plotting will self update without the cell having to be rerun.

# %%
## Must be ran so that the dropdown menus can be generated.
from Interactive_Climate_Visualization import City_Temperature_Timeseries_Analysis

City_Temperature_Timeseries_Analysis()
# Out:
# ...
# <div>                            <div id="d6933c00-bfe9-42e0-b263-f5b9b1809ead" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6933c00-bfe9-42e0-b263-f5b9b1809ead")) {                    Plotly.newPlot(                        "d6933c00-bfe9-42e0-b263-f5b9b1809ead",                        [{"mode":"lines+markers","name":"Average Temperature","x":[1892,1893,1894,1895,1896,1897,1898,1899,1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973
# ...
